# %% [markdown]
# # Women in Movies

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# ### Loading the Data into a Data Frame

# %%
# Loading the data into the data frame.

df = pd.read_csv('Movies.csv')
# To display the top 5 rows
df.head()
# Out:
#    BechdelRating     imdbid  BechdelId  \
# 0            1.0  tt0229440     5274.0
# 1            3.0  tt0233298     3387.0
# 2            3.0  tt0286137     4172.0
# 3            1.0  tt0181984      625.0
# 4            3.0  tt0260191     4835.0
#
#                                     Title  Year     Released  Runtime  \
# 0                     Hellraiser: Inferno  2000  03 Oct 2000   99 min
# 1      Batman Beyond: Return of the Joker  2000  12 Dec 2000   76 min
# 2                    Something Between Us  2000  16 Dec 2000   79 min
# 3                             Boiler Room  2000  18 Feb 2000  120 min
# 4  Gundam Wing: The Movie - Endless Waltz  1998  10 Nov 2000  180 min
#
#                                         Genre           Director  \
# 0            Crime, Horror, Mystery, Thriller   Scott Derrickson
# 1  Animation, Action, Crime, Sci-Fi, Thriller          Curt Geda
# 2                             Comedy, Romance  George Thomas Jr.
# 3                      Crime, Drama, Thriller        Ben Younger
# 4            Animation, Action, Drama, Sci-Fi       Yasunao Aoki
#
#                                               Writer  ...  \
# 0  Clive Barker (characters), Paul Harris Boardma...  ...
# 1  Bob Kane (character created by: Batman), Paul ...  ...
# 2                                  George Thomas Jr.  ...
# 3                                        Ben Younger  ...
# 4  Rika Takahashi (translation), Yoshiyuki Tomino...  ...
#
#                                                 Plot          Language  \
# 0  A shady police detective becomes embroiled in ...           English
# 1  The Joker is back with a vengeance, and Gotham...           English
# 2                                                NaN           English
# 3  A college dropout, attempting to live up to hi...  English, Russian
# 4  After Colony 196, Treize Kushrenada is dead an...           English
#
#   Country                   Awards  \
# 0     USA   1 win & 3 nominations.
# 1     USA  3 wins & 5 nominations.
# 2     USA                   1 win.
# 3     USA   1 win & 9 nominations.
# 4   Japan                      NaN
#
#                                              Ratings Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       NaN         5.5
# 1  [{'Source': 'Internet Movie Database', 'Value'...       NaN         7.8
# 2  [{'Source': 'Internet Movie Database', 'Value'...       NaN         6.7
# 3  [{'Source': 'Internet Movie Database', 'Value'...      63.0         7.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       NaN         7.9
#
#    imdbVotes BoxOffice                   Production
# 0     14,299       NaN                      Miramax
# 1     22,149       NaN            Warner Home Video
# 2         13       NaN                          NaN
# 3     47,574       NaN  New Line Home Entertainment
# 4      2,165       NaN                          NaN
#
# [5 rows x 21 columns]

# %%
# To display the bottom 5 rows
df.tail(5)
# Out:
#       BechdelRating      imdbid  BechdelId                     Title  Year  \
# 5110            3.0   tt6513120     8679.0   Fighting with My Family  2019
# 5111            0.0   tt8151874     8965.0                 Honey Boy  2019
# 5112            3.0   tt8461042     8859.0  The Marijuana Conspiracy  2020
# 5113            3.0   tt7545266     8964.0               Like a Boss  2020
# 5114            3.0  tt10781754     8811.0        AmeriCaN_TeRRoRiST  2021
#
#          Released  Runtime                            Genre  \
# 5110  22 Feb 2019  108 min  Biography, Comedy, Drama, Sport
# 5111  27 Nov 2019   94 min                            Drama
# 5112  18 Jan 2020  124 min                              NaN
# 5113  10 Jan 2020   83 min                           Comedy
# 5114  20 Apr 2021      NaN               Documentary, Short
#
#                    Director  \
# 5110       Stephen Merchant
# 5111            Alma Har'el
# 5112            Craig Pryce
# 5113          Miguel Arteta
# 5114  Joseph Daniel Bonczyk
#
#                                                  Writer  ...  \
# 5110                                   Stephen Merchant  ...
# 5111                                       Shia LaBeouf  ...
# 5112                                        Craig Pryce  ...
# 5113  Sam Pitman (screenplay by), Adam Cole-Kelly (s...  ...
# 5114                                      Kathy DiTondo  ...
#
#                                                    Plot          Language  \
# 5110  A former wrestler and his family make a living...           English
# 5111  A young actor's stormy childhood and early adu...  English, Spanish
# 5112  In 1972, young women looking for a fresh start...           English
# 5113  Two friends with very different ideals start a...           English
# 5114  A new film by Joseph D. Bonczyk. This endeavor...           English
#
#               Country                    Awards  \
# 5110  UK, USA, Mexico  10 wins & 2 nominations.
# 5111              USA  9 wins & 33 nominations.
# 5112           Canada                       NaN
# 5113              USA                       NaN
# 5114              USA                       NaN
#
#                                                 Ratings Metascore  imdbRating  \
# 5110  [{'Source': 'Internet Movie Database', 'Value'...      68.0         7.1
# 5111  [{'Source': 'Internet Movie Database', 'Value'...      73.0         7.4
# 5112                                                 []       NaN         NaN
# 5113  [{'Source': 'Internet Movie Database', 'Value'...      33.0         4.3
# 5114                                                 []       NaN         NaN
#
#       imdbVotes BoxOffice          Production
# 5110     54,112       NaN                 MGM
# 5111     11,841       NaN      Amazon Studios
# 5112        NaN       NaN                 NaN
# 5113      2,633       NaN  Paramount Pictures
# 5114        NaN       NaN                 NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Checking the data type

# %%
# Checking the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5115 entries, 0 to 5114
# Data columns (total 21 columns):
# BechdelRating    5115 non-null float64
# imdbid           5115 non-null object
# BechdelId        5115 non-null float64
# Title            5115 non-null object
# Year             5115 non-null int64
# Released         5070 non-null object
# Runtime          5091 non-null object
# Genre            5108 non-null object
# Director         5111 non-null object
# Writer           5067 non-null object
# Actors           5106 non-null object
# Plot             5083 non-null object
# Language         5100 non-null object
# Country          5109 non-null object
# Awards           4353 non-null object
# Ratings          5115 non-null object
# Metascore        3764 non-null float64
# imdbRating       5091 non-null float64
# imdbVotes        5091 non-null object
# BoxOffice        2641 non-null object
# Production       4477 non-null object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 839.3+ KB

# %% [markdown]
# ### Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ### Dropping irrelevant columns

# %%
# Dropping irrelevant columns
df = df.drop([‘Engine Fuel Type’, ‘Market Category’, ‘Vehicle Style’, ‘Popularity’, ‘Number of Doors’, ‘Vehicle Size’], axis=1)
df.head(5)

# %% [markdown]
# ### Detecting missing or null values

# %%
# Finding the null values.
print(df.isnull().sum())
